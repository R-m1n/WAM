# %%
import pandas as pd

from pathlib import Path

from BlockCluster import BlockCluster

# %%
script_path = Path().resolve()
data_path = script_path / "data/dummy.csv"

# %%
dataframe = pd.read_csv(data_path).set_index('ID')

features = dataframe.iloc[:, :-1].to_numpy()

# %%
b_cluster = BlockCluster()

features_transformed = b_cluster.fit_transform(features)

# %%
b_cluster.plot_nmi_matrix()

# %%
b_cluster.plot_clusters()

# %%
b_cluster.plot_change_points()
